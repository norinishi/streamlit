# %%
import streamlit as st
import numpy as np
import pandas as pd

st.title('Streamlit 入門')

st.write('DataFrame')

# %%
df = pd.DataFrame(
    np.random.rand(100,2)/[50,50] + [35.69, 139.70],
    columns=['lat','lon']
)
df
# Out:
#           lat         lon
# 0   35.690230  139.719175
# 1   35.699089  139.714923
# 2   35.692495  139.709201
# 3   35.696579  139.700035
# 4   35.701105  139.711348
# ..        ...         ...
# 95  35.702482  139.711696
# 96  35.705365  139.713773
# 97  35.705325  139.711445
# 98  35.690022  139.711708
# 99  35.704593  139.713717
#
# [100 rows x 2 columns]
